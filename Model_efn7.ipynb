# %% [markdown]
# #### Thanks to https://www.kaggle.com/xhlulu/ranzcr-efficientnet-tpu-training

# %%
# !pip install efficientnet -q
# Out:
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
import os

import efficientnet.tfkeras as efn
import numpy as np
import pandas as pd
from kaggle_datasets import KaggleDatasets
from sklearn.model_selection import train_test_split
import tensorflow as tf
from sklearn.model_selection import GroupKFold

# %%
def auto_select_accelerator():
    try:
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
        tf.config.experimental_connect_to_cluster(tpu)
        tf.tpu.experimental.initialize_tpu_system(tpu)
        strategy = tf.distribute.experimental.TPUStrategy(tpu)
        print("Running on TPU:", tpu.master())
    except ValueError:
        strategy = tf.distribute.get_strategy()
    print(f"Running on {strategy.num_replicas_in_sync} replicas")
    
    return strategy


def build_decoder(with_labels=True, target_size=(256, 256), ext='jpg'):
    def decode(path):
        file_bytes = tf.io.read_file(path)

        if ext == 'png':
            img = tf.image.decode_png(file_bytes, channels=3)
        elif ext in ['jpg', 'jpeg']:
            img = tf.image.decode_jpeg(file_bytes, channels=3)
        else:
            raise ValueError("Image extension not supported")
        img = tf.cast(img, tf.float32) / 255.0
        img = tf.image.resize(img, target_size)

        return img
    
    def decode_with_labels(path, label):
        return decode(path), label
    
    return decode_with_labels if with_labels else decode


def build_augmenter(with_labels=True):
    def augment(img):
        img = tf.image.random_flip_left_right(img)
        img = tf.image.random_flip_up_down(img)
        return img
    
    def augment_with_labels(img, label):
        return augment(img), label
    
    return augment_with_labels if with_labels else augment


def build_dataset(paths, labels=None, bsize=128, cache=True,
                  decode_fn=None, augment_fn=None,
                  augment=True, repeat=True, shuffle=1024, 
                  cache_dir=""):
    if cache_dir != "" and cache is True:
        os.makedirs(cache_dir, exist_ok=True)
    
    if decode_fn is None:
        decode_fn = build_decoder(labels is not None)
    
    if augment_fn is None:
        augment_fn = build_augmenter(labels is not None)
    
    AUTO = tf.data.experimental.AUTOTUNE
    slices = paths if labels is None else (paths, labels)
    
    dset = tf.data.Dataset.from_tensor_slices(slices)
    dset = dset.map(decode_fn, num_parallel_calls=AUTO)
    dset = dset.cache(cache_dir) if cache else dset
    dset = dset.map(augment_fn, num_parallel_calls=AUTO) if augment else dset
    dset = dset.repeat() if repeat else dset
    dset = dset.shuffle(shuffle) if shuffle else dset
    dset = dset.batch(bsize).prefetch(AUTO)
    
    return dset

# %%
COMPETITION_NAME = "siimcovid19-512-img-png-600-study-png"
strategy = auto_select_accelerator()
BATCH_SIZE = strategy.num_replicas_in_sync * 16
GCS_DS_PATH = KaggleDatasets().get_gcs_path(COMPETITION_NAME)
# Out:
# Running on TPU: grpc://10.0.0.2:8470
# Running on 8 replicas

# %%
load_dir = f"/kaggle/input/{COMPETITION_NAME}/"
df = pd.read_csv('../input/siim-covid19-detection/train_study_level.csv')
label_cols = df.columns[1:5]

# %%
gkf  = GroupKFold(n_splits = 5)
df['fold'] = -1
for fold, (train_idx, val_idx) in enumerate(gkf.split(df, groups = df.id.tolist())):
    df.loc[val_idx, 'fold'] = fold

# %%
for i in range(5):
    
    valid_paths = GCS_DS_PATH + '/study/' + df[df['fold'] == i]['id'] + '.png' #"/train/"
    train_paths = GCS_DS_PATH + '/study/' + df[df['fold'] != i]['id'] + '.png' #"/train/" 
    valid_labels = df[df['fold'] == i][label_cols].values
    train_labels = df[df['fold'] != i][label_cols].values

    IMSIZE = (224, 240, 260, 300, 380, 456, 528, 600)
    IMS = 7

    decoder = build_decoder(with_labels=True, target_size=(IMSIZE[IMS], IMSIZE[IMS]), ext='png')
    test_decoder = build_decoder(with_labels=False, target_size=(IMSIZE[IMS], IMSIZE[IMS]),ext='png')

    train_dataset = build_dataset(
        train_paths, train_labels, bsize=BATCH_SIZE, decode_fn=decoder
    )

    valid_dataset = build_dataset(
        valid_paths, valid_labels, bsize=BATCH_SIZE, decode_fn=decoder,
        repeat=False, shuffle=False, augment=False
    )

    try:
        n_labels = train_labels.shape[1]
    except:
        n_labels = 1

    with strategy.scope():
        model = tf.keras.Sequential([
            efn.EfficientNetB7(
                input_shape=(IMSIZE[IMS], IMSIZE[IMS], 3),
                weights='imagenet',
                include_top=False),
            tf.keras.layers.GlobalAveragePooling2D(),
            tf.keras.layers.Dense(n_labels, activation='softmax')
        ])
        model.compile(
            optimizer=tf.keras.optimizers.Adam(),
            loss='categorical_crossentropy',
            metrics=[tf.keras.metrics.AUC(multi_label=True)])

        model.summary()


    steps_per_epoch = train_paths.shape[0] // BATCH_SIZE
    checkpoint = tf.keras.callbacks.ModelCheckpoint(
        f'model{i}.h5', save_best_only=True, monitor='val_loss', mode='min')
    lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", patience=3, min_lr=1e-6, mode='min')

    history = model.fit(
        train_dataset, 
        epochs=40,
        verbose=1,
        callbacks=[checkpoint, lr_reducer],
        steps_per_epoch=steps_per_epoch,
        validation_data=valid_dataset)

    hist_df = pd.DataFrame(history.history)
    hist_df.to_csv(f'history{i}.csv')
# Out:
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b7_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 258441216/258434480 [==============================] - 3s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b7 (Functional) (None, 19, 19, 2560)      64097680
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2560)              0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 10244
# =================================================================
# Total params: 64,107,924
# Trainable params: 63,797,204
# Non-trainable params: 310,720
# _________________________________________________________________
# Epoch 1/40
# 37/37 [==============================] - 392s 4s/step - loss: 1.1822 - auc: 0.6302 - val_loss: 1.3078 - val_auc: 0.6951
# Epoch 2/40
# 37/37 [==============================] - 57s 2s/step - loss: 1.0250 - auc: 0.7043 - val_loss: 1.8330 - val_auc: 0.6919
# Epoch 3/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.9508 - auc: 0.7493 - val_loss: 0.9986 - val_auc: 0.7517
# Epoch 4/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.9137 - auc: 0.7759 - val_loss: 0.9523 - val_auc: 0.7779
# Epoch 5/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.8840 - auc: 0.7891 - val_loss: 0.9970 - val_auc: 0.7891
# Epoch 6/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.8588 - auc: 0.8018 - val_loss: 1.1077 - val_auc: 0.7458
# Epoch 7/40
# 37/37 [==============================] - 58s 2s/step - loss: 0.8553 - auc: 0.8169 - val_loss: 1.6721 - val_auc: 0.7180
# Epoch 8/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.8133 - auc: 0.8343 - val_loss: 0.9955 - val_auc: 0.7847
# Epoch 9/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.7605 - auc: 0.8543 - val_loss: 0.9023 - val_auc: 0.7964
# Epoch 10/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.7438 - auc: 0.8595 - val_loss: 0.8862 - val_auc: 0.7971
# Epoch 11/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.7004 - auc: 0.8756 - val_loss: 0.8778 - val_auc: 0.7947
# Epoch 12/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6967 - auc: 0.8789 - val_loss: 0.8724 - val_auc: 0.7961
# Epoch 13/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6754 - auc: 0.8851 - val_loss: 0.8950 - val_auc: 0.7905
# Epoch 14/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6307 - auc: 0.8960 - val_loss: 0.9129 - val_auc: 0.7963
# Epoch 15/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6083 - auc: 0.9041 - val_loss: 0.9228 - val_auc: 0.7907
# Epoch 16/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.5977 - auc: 0.9109 - val_loss: 0.9368 - val_auc: 0.7924
# Epoch 17/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5882 - auc: 0.9130 - val_loss: 0.9490 - val_auc: 0.7927
# Epoch 18/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5562 - auc: 0.9225 - val_loss: 0.9603 - val_auc: 0.7914
# Epoch 19/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5704 - auc: 0.9219 - val_loss: 0.9664 - val_auc: 0.7929
# Epoch 20/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5605 - auc: 0.9241 - val_loss: 0.9706 - val_auc: 0.7932
# Epoch 21/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5642 - auc: 0.9217 - val_loss: 0.9747 - val_auc: 0.7936
# Epoch 22/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5651 - auc: 0.9220 - val_loss: 0.9786 - val_auc: 0.7937
# Epoch 23/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5540 - auc: 0.9263 - val_loss: 0.9833 - val_auc: 0.7917
# Epoch 24/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5671 - auc: 0.9190 - val_loss: 0.9855 - val_auc: 0.7921
# Epoch 25/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5570 - auc: 0.9250 - val_loss: 0.9870 - val_auc: 0.7927
# Epoch 26/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5726 - auc: 0.9177 - val_loss: 0.9879 - val_auc: 0.7929
# Epoch 27/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5555 - auc: 0.9222 - val_loss: 0.9895 - val_auc: 0.7930
# Epoch 28/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5687 - auc: 0.9139 - val_loss: 0.9905 - val_auc: 0.7925
# Epoch 29/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5772 - auc: 0.9180 - val_loss: 0.9925 - val_auc: 0.7927
# Epoch 30/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.5553 - auc: 0.9228 - val_loss: 0.9932 - val_auc: 0.7924
# Epoch 31/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5602 - auc: 0.9211 - val_loss: 0.9930 - val_auc: 0.7927
# Epoch 32/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5625 - auc: 0.9208 - val_loss: 0.9931 - val_auc: 0.7927
# Epoch 33/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5771 - auc: 0.9199 - val_loss: 0.9925 - val_auc: 0.7923
# Epoch 34/40
# 37/37 [==============================] - 59s 2s/step - loss: 0.5551 - auc: 0.9226 - val_loss: 0.9946 - val_auc: 0.7924
# Epoch 35/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5414 - auc: 0.9293 - val_loss: 0.9935 - val_auc: 0.7915
# Epoch 36/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5789 - auc: 0.9142 - val_loss: 0.9949 - val_auc: 0.7925
# Epoch 37/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5817 - auc: 0.9140 - val_loss: 0.9948 - val_auc: 0.7922
# Epoch 38/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5622 - auc: 0.9230 - val_loss: 0.9961 - val_auc: 0.7922
# Epoch 39/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5774 - auc: 0.9175 - val_loss: 0.9958 - val_auc: 0.7929
# Epoch 40/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5566 - auc: 0.9214 - val_loss: 0.9960 - val_auc: 0.7918
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b7 (Functional) (None, 19, 19, 2560)      64097680
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2560)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 10244
# =================================================================
# Total params: 64,107,924
# Trainable params: 63,797,204
# Non-trainable params: 310,720
# _________________________________________________________________
# Epoch 1/40
# 37/37 [==============================] - 354s 4s/step - loss: 1.1775 - auc_1: 0.6227 - val_loss: 1.2679 - val_auc_1: 0.6874
# Epoch 2/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.9871 - auc_1: 0.7229 - val_loss: 1.2414 - val_auc_1: 0.7223
# Epoch 3/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.9261 - auc_1: 0.7500 - val_loss: 1.1132 - val_auc_1: 0.7523
# Epoch 4/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.9120 - auc_1: 0.7782 - val_loss: 1.2273 - val_auc_1: 0.7237
# Epoch 5/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.8834 - auc_1: 0.7849 - val_loss: 1.1281 - val_auc_1: 0.7593
# Epoch 6/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.8610 - auc_1: 0.8027 - val_loss: 1.2865 - val_auc_1: 0.7183
# Epoch 7/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.8343 - auc_1: 0.8223 - val_loss: 1.1014 - val_auc_1: 0.7707
# Epoch 8/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.7679 - auc_1: 0.8452 - val_loss: 1.0186 - val_auc_1: 0.7753
# Epoch 9/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.7419 - auc_1: 0.8570 - val_loss: 0.9776 - val_auc_1: 0.7842
# Epoch 10/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.7333 - auc_1: 0.8568 - val_loss: 0.9594 - val_auc_1: 0.7845
# Epoch 11/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.7002 - auc_1: 0.8743 - val_loss: 0.9671 - val_auc_1: 0.7863
# Epoch 12/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.7043 - auc_1: 0.8676 - val_loss: 0.9813 - val_auc_1: 0.7864
# Epoch 13/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.6543 - auc_1: 0.8880 - val_loss: 0.9917 - val_auc_1: 0.7858
# Epoch 14/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.6392 - auc_1: 0.8951 - val_loss: 0.9977 - val_auc_1: 0.7872
# Epoch 15/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.6160 - auc_1: 0.8960 - val_loss: 1.0050 - val_auc_1: 0.7891
# Epoch 16/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.6146 - auc_1: 0.8999 - val_loss: 1.0085 - val_auc_1: 0.7898
# Epoch 17/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6168 - auc_1: 0.9034 - val_loss: 1.0119 - val_auc_1: 0.7900
# Epoch 18/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.5891 - auc_1: 0.9090 - val_loss: 1.0158 - val_auc_1: 0.7900
# Epoch 19/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.6347 - auc_1: 0.8988 - val_loss: 1.0206 - val_auc_1: 0.7894
# Epoch 20/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.6161 - auc_1: 0.8980 - val_loss: 1.0225 - val_auc_1: 0.7903
# Epoch 21/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.6181 - auc_1: 0.8954 - val_loss: 1.0252 - val_auc_1: 0.7907
# Epoch 22/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.6132 - auc_1: 0.9042 - val_loss: 1.0249 - val_auc_1: 0.7906
# Epoch 23/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.6029 - auc_1: 0.9057 - val_loss: 1.0240 - val_auc_1: 0.7910
# Epoch 24/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.6070 - auc_1: 0.9040 - val_loss: 1.0234 - val_auc_1: 0.7913
# Epoch 25/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.6051 - auc_1: 0.9027 - val_loss: 1.0244 - val_auc_1: 0.7916
# Epoch 26/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.5971 - auc_1: 0.9097 - val_loss: 1.0258 - val_auc_1: 0.7917
# Epoch 27/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.6083 - auc_1: 0.9043 - val_loss: 1.0251 - val_auc_1: 0.7927
# Epoch 28/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.5860 - auc_1: 0.9108 - val_loss: 1.0256 - val_auc_1: 0.7919
# Epoch 29/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.6262 - auc_1: 0.8999 - val_loss: 1.0254 - val_auc_1: 0.7924
# Epoch 30/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.6030 - auc_1: 0.9070 - val_loss: 1.0247 - val_auc_1: 0.7922
# Epoch 31/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.6085 - auc_1: 0.9048 - val_loss: 1.0252 - val_auc_1: 0.7922
# Epoch 32/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.5828 - auc_1: 0.9114 - val_loss: 1.0268 - val_auc_1: 0.7919
# Epoch 33/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.6056 - auc_1: 0.9053 - val_loss: 1.0284 - val_auc_1: 0.7921
# Epoch 34/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.5899 - auc_1: 0.9094 - val_loss: 1.0288 - val_auc_1: 0.7921
# Epoch 35/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5744 - auc_1: 0.9122 - val_loss: 1.0303 - val_auc_1: 0.7918
# Epoch 36/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.5807 - auc_1: 0.9135 - val_loss: 1.0306 - val_auc_1: 0.7921
# Epoch 37/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.5932 - auc_1: 0.9072 - val_loss: 1.0321 - val_auc_1: 0.7911
# Epoch 38/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.5914 - auc_1: 0.9088 - val_loss: 1.0338 - val_auc_1: 0.7911
# Epoch 39/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.5736 - auc_1: 0.9144 - val_loss: 1.0330 - val_auc_1: 0.7909
# Epoch 40/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.5945 - auc_1: 0.9091 - val_loss: 1.0344 - val_auc_1: 0.7911
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b7 (Functional) (None, 19, 19, 2560)      64097680
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 2560)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 10244
# =================================================================
# Total params: 64,107,924
# Trainable params: 63,797,204
# Non-trainable params: 310,720
# _________________________________________________________________
# Epoch 1/40
# 37/37 [==============================] - 346s 3s/step - loss: 1.1825 - auc_2: 0.6252 - val_loss: 1.4204 - val_auc_2: 0.6922
# Epoch 2/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.9958 - auc_2: 0.7086 - val_loss: 1.3771 - val_auc_2: 0.7112
# Epoch 3/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.9927 - auc_2: 0.7375 - val_loss: 1.0377 - val_auc_2: 0.7675
# Epoch 4/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.9265 - auc_2: 0.7659 - val_loss: 1.0522 - val_auc_2: 0.7781
# Epoch 5/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.8998 - auc_2: 0.7887 - val_loss: 1.1687 - val_auc_2: 0.7318
# Epoch 6/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.8618 - auc_2: 0.8033 - val_loss: 0.9254 - val_auc_2: 0.7813
# Epoch 7/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.8482 - auc_2: 0.8087 - val_loss: 0.9924 - val_auc_2: 0.7872
# Epoch 8/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.8451 - auc_2: 0.8077 - val_loss: 0.9299 - val_auc_2: 0.7746
# Epoch 9/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.8125 - auc_2: 0.8312 - val_loss: 0.9415 - val_auc_2: 0.7901
# Epoch 10/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.7548 - auc_2: 0.8494 - val_loss: 0.8974 - val_auc_2: 0.7996
# Epoch 11/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6804 - auc_2: 0.8795 - val_loss: 0.8923 - val_auc_2: 0.8017
# Epoch 12/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6599 - auc_2: 0.8865 - val_loss: 0.9217 - val_auc_2: 0.8018
# Epoch 13/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6367 - auc_2: 0.8946 - val_loss: 0.9448 - val_auc_2: 0.7982
# Epoch 14/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6108 - auc_2: 0.9042 - val_loss: 0.9339 - val_auc_2: 0.7973
# Epoch 15/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5868 - auc_2: 0.9118 - val_loss: 0.9442 - val_auc_2: 0.7985
# Epoch 16/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5788 - auc_2: 0.9154 - val_loss: 0.9524 - val_auc_2: 0.7983
# Epoch 17/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5752 - auc_2: 0.9123 - val_loss: 0.9588 - val_auc_2: 0.7983
# Epoch 18/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5789 - auc_2: 0.9125 - val_loss: 0.9628 - val_auc_2: 0.7986
# Epoch 19/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5833 - auc_2: 0.9099 - val_loss: 0.9653 - val_auc_2: 0.7985
# Epoch 20/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5674 - auc_2: 0.9169 - val_loss: 0.9681 - val_auc_2: 0.7999
# Epoch 21/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5942 - auc_2: 0.9113 - val_loss: 0.9697 - val_auc_2: 0.8012
# Epoch 22/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5881 - auc_2: 0.9109 - val_loss: 0.9717 - val_auc_2: 0.8008
# Epoch 23/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5956 - auc_2: 0.9090 - val_loss: 0.9725 - val_auc_2: 0.8009
# Epoch 24/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5665 - auc_2: 0.9138 - val_loss: 0.9721 - val_auc_2: 0.8011
# Epoch 25/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5683 - auc_2: 0.9214 - val_loss: 0.9727 - val_auc_2: 0.8010
# Epoch 26/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5591 - auc_2: 0.9218 - val_loss: 0.9737 - val_auc_2: 0.8008
# Epoch 27/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5445 - auc_2: 0.9213 - val_loss: 0.9733 - val_auc_2: 0.8009
# Epoch 28/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5485 - auc_2: 0.9249 - val_loss: 0.9752 - val_auc_2: 0.8003
# Epoch 29/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5740 - auc_2: 0.9137 - val_loss: 0.9748 - val_auc_2: 0.8004
# Epoch 30/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5676 - auc_2: 0.9150 - val_loss: 0.9750 - val_auc_2: 0.8008
# Epoch 31/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5605 - auc_2: 0.9182 - val_loss: 0.9741 - val_auc_2: 0.8010
# Epoch 32/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5496 - auc_2: 0.9220 - val_loss: 0.9731 - val_auc_2: 0.8008
# Epoch 33/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5353 - auc_2: 0.9296 - val_loss: 0.9758 - val_auc_2: 0.8007
# Epoch 34/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5669 - auc_2: 0.9160 - val_loss: 0.9744 - val_auc_2: 0.8009
# Epoch 35/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5607 - auc_2: 0.9154 - val_loss: 0.9732 - val_auc_2: 0.8009
# Epoch 36/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5428 - auc_2: 0.9246 - val_loss: 0.9768 - val_auc_2: 0.8005
# Epoch 37/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5768 - auc_2: 0.9125 - val_loss: 0.9778 - val_auc_2: 0.8004
# Epoch 38/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5814 - auc_2: 0.9138 - val_loss: 0.9779 - val_auc_2: 0.8001
# Epoch 39/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5756 - auc_2: 0.9125 - val_loss: 0.9796 - val_auc_2: 0.8002
# Epoch 40/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.5447 - auc_2: 0.9243 - val_loss: 0.9790 - val_auc_2: 0.8003
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b7 (Functional) (None, 19, 19, 2560)      64097680
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 2560)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 10244
# =================================================================
# Total params: 64,107,924
# Trainable params: 63,797,204
# Non-trainable params: 310,720
# _________________________________________________________________
# Epoch 1/40
# 37/37 [==============================] - 368s 4s/step - loss: 1.1714 - auc_3: 0.6358 - val_loss: 1.3964 - val_auc_3: 0.7058
# Epoch 2/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.9831 - auc_3: 0.7235 - val_loss: 1.2322 - val_auc_3: 0.7476
# Epoch 3/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.9427 - auc_3: 0.7558 - val_loss: 1.7025 - val_auc_3: 0.7353
# Epoch 4/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.9125 - auc_3: 0.7776 - val_loss: 1.1265 - val_auc_3: 0.7616
# Epoch 5/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.9072 - auc_3: 0.7841 - val_loss: 0.8848 - val_auc_3: 0.7858
# Epoch 6/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.8615 - auc_3: 0.8036 - val_loss: 1.1333 - val_auc_3: 0.7435
# Epoch 7/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.8616 - auc_3: 0.8042 - val_loss: 1.0323 - val_auc_3: 0.7727
# Epoch 8/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.8181 - auc_3: 0.8291 - val_loss: 1.1063 - val_auc_3: 0.7488
# Epoch 9/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.7755 - auc_3: 0.8456 - val_loss: 0.9846 - val_auc_3: 0.7861
# Epoch 10/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.7168 - auc_3: 0.8704 - val_loss: 0.9692 - val_auc_3: 0.7888
# Epoch 11/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.7169 - auc_3: 0.8754 - val_loss: 0.9480 - val_auc_3: 0.7897
# Epoch 12/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6507 - auc_3: 0.8924 - val_loss: 0.9419 - val_auc_3: 0.7898
# Epoch 13/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6533 - auc_3: 0.8888 - val_loss: 0.9348 - val_auc_3: 0.7914
# Epoch 14/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6601 - auc_3: 0.8908 - val_loss: 0.9296 - val_auc_3: 0.7898
# Epoch 15/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6625 - auc_3: 0.8850 - val_loss: 0.9284 - val_auc_3: 0.7903
# Epoch 16/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6462 - auc_3: 0.8886 - val_loss: 0.9273 - val_auc_3: 0.7893
# Epoch 17/40
# 37/37 [==============================] - 60s 2s/step - loss: 0.6689 - auc_3: 0.8851 - val_loss: 0.9284 - val_auc_3: 0.7901
# Epoch 18/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6481 - auc_3: 0.8922 - val_loss: 0.9295 - val_auc_3: 0.7907
# Epoch 19/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6291 - auc_3: 0.8972 - val_loss: 0.9316 - val_auc_3: 0.7926
# Epoch 20/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6703 - auc_3: 0.8859 - val_loss: 0.9325 - val_auc_3: 0.7924
# Epoch 21/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6411 - auc_3: 0.8970 - val_loss: 0.9345 - val_auc_3: 0.7923
# Epoch 22/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6375 - auc_3: 0.8982 - val_loss: 0.9373 - val_auc_3: 0.7922
# Epoch 23/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6481 - auc_3: 0.8948 - val_loss: 0.9399 - val_auc_3: 0.7929
# Epoch 24/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6615 - auc_3: 0.8894 - val_loss: 0.9413 - val_auc_3: 0.7933
# Epoch 25/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6468 - auc_3: 0.8924 - val_loss: 0.9420 - val_auc_3: 0.7927
# Epoch 26/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6197 - auc_3: 0.9011 - val_loss: 0.9435 - val_auc_3: 0.7932
# Epoch 27/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6353 - auc_3: 0.8942 - val_loss: 0.9449 - val_auc_3: 0.7924
# Epoch 28/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6317 - auc_3: 0.8964 - val_loss: 0.9463 - val_auc_3: 0.7923
# Epoch 29/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6448 - auc_3: 0.8949 - val_loss: 0.9454 - val_auc_3: 0.7928
# Epoch 30/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6349 - auc_3: 0.8987 - val_loss: 0.9466 - val_auc_3: 0.7925
# Epoch 31/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6417 - auc_3: 0.8928 - val_loss: 0.9466 - val_auc_3: 0.7922
# Epoch 32/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6471 - auc_3: 0.8886 - val_loss: 0.9481 - val_auc_3: 0.7913
# Epoch 33/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6294 - auc_3: 0.8955 - val_loss: 0.9475 - val_auc_3: 0.7919
# Epoch 34/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6258 - auc_3: 0.8983 - val_loss: 0.9473 - val_auc_3: 0.7923
# Epoch 35/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6339 - auc_3: 0.8954 - val_loss: 0.9475 - val_auc_3: 0.7917
# Epoch 36/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6271 - auc_3: 0.9000 - val_loss: 0.9488 - val_auc_3: 0.7920
# Epoch 37/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.6226 - auc_3: 0.8996 - val_loss: 0.9492 - val_auc_3: 0.7919
# Epoch 38/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6158 - auc_3: 0.8983 - val_loss: 0.9482 - val_auc_3: 0.7915
# Epoch 39/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6429 - auc_3: 0.8955 - val_loss: 0.9477 - val_auc_3: 0.7920
# Epoch 40/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6417 - auc_3: 0.8930 - val_loss: 0.9487 - val_auc_3: 0.7915
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b7 (Functional) (None, 19, 19, 2560)      64097680
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 2560)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 10244
# =================================================================
# Total params: 64,107,924
# Trainable params: 63,797,204
# Non-trainable params: 310,720
# _________________________________________________________________
# Epoch 1/40
# 37/37 [==============================] - 353s 3s/step - loss: 1.1745 - auc_4: 0.6219 - val_loss: 1.2333 - val_auc_4: 0.7041
# Epoch 2/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.9841 - auc_4: 0.7213 - val_loss: 1.8502 - val_auc_4: 0.6698
# Epoch 3/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.9439 - auc_4: 0.7496 - val_loss: 1.1887 - val_auc_4: 0.7629
# Epoch 4/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.8834 - auc_4: 0.7768 - val_loss: 0.9447 - val_auc_4: 0.7963
# Epoch 5/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.8842 - auc_4: 0.7893 - val_loss: 0.9713 - val_auc_4: 0.7852
# Epoch 6/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.8617 - auc_4: 0.8004 - val_loss: 1.0260 - val_auc_4: 0.7892
# Epoch 7/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.8429 - auc_4: 0.8052 - val_loss: 1.4440 - val_auc_4: 0.7311
# Epoch 8/40
# 37/37 [==============================] - 56s 2s/step - loss: 0.7962 - auc_4: 0.8362 - val_loss: 0.9787 - val_auc_4: 0.7922
# Epoch 9/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.7391 - auc_4: 0.8601 - val_loss: 0.9574 - val_auc_4: 0.8021
# Epoch 10/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.7144 - auc_4: 0.8604 - val_loss: 0.9530 - val_auc_4: 0.8050
# Epoch 11/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6904 - auc_4: 0.8728 - val_loss: 0.9470 - val_auc_4: 0.8057
# Epoch 12/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6574 - auc_4: 0.8791 - val_loss: 0.9428 - val_auc_4: 0.8070
# Epoch 13/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6747 - auc_4: 0.8820 - val_loss: 0.9419 - val_auc_4: 0.8073
# Epoch 14/40
# 37/37 [==============================] - 59s 2s/step - loss: 0.6724 - auc_4: 0.8834 - val_loss: 0.9421 - val_auc_4: 0.8074
# Epoch 15/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6653 - auc_4: 0.8812 - val_loss: 0.9410 - val_auc_4: 0.8077
# Epoch 16/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6563 - auc_4: 0.8857 - val_loss: 0.9450 - val_auc_4: 0.8070
# Epoch 17/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6546 - auc_4: 0.8871 - val_loss: 0.9432 - val_auc_4: 0.8076
# Epoch 18/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6405 - auc_4: 0.8877 - val_loss: 0.9450 - val_auc_4: 0.8081
# Epoch 19/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6608 - auc_4: 0.8893 - val_loss: 0.9487 - val_auc_4: 0.8076
# Epoch 20/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6359 - auc_4: 0.8982 - val_loss: 0.9531 - val_auc_4: 0.8067
# Epoch 21/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6644 - auc_4: 0.8885 - val_loss: 0.9555 - val_auc_4: 0.8066
# Epoch 22/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6341 - auc_4: 0.8914 - val_loss: 0.9574 - val_auc_4: 0.8070
# Epoch 23/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6526 - auc_4: 0.8897 - val_loss: 0.9590 - val_auc_4: 0.8077
# Epoch 24/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6463 - auc_4: 0.8907 - val_loss: 0.9595 - val_auc_4: 0.8079
# Epoch 25/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6608 - auc_4: 0.8859 - val_loss: 0.9599 - val_auc_4: 0.8078
# Epoch 26/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6488 - auc_4: 0.8906 - val_loss: 0.9597 - val_auc_4: 0.8077
# Epoch 27/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6487 - auc_4: 0.8894 - val_loss: 0.9620 - val_auc_4: 0.8071
# Epoch 28/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6415 - auc_4: 0.8935 - val_loss: 0.9619 - val_auc_4: 0.8070
# Epoch 29/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6393 - auc_4: 0.8937 - val_loss: 0.9614 - val_auc_4: 0.8064
# Epoch 30/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6493 - auc_4: 0.8863 - val_loss: 0.9610 - val_auc_4: 0.8065
# Epoch 31/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6401 - auc_4: 0.8928 - val_loss: 0.9612 - val_auc_4: 0.8062
# Epoch 32/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6592 - auc_4: 0.8867 - val_loss: 0.9616 - val_auc_4: 0.8068
# Epoch 33/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6500 - auc_4: 0.8907 - val_loss: 0.9627 - val_auc_4: 0.8063
# Epoch 34/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6528 - auc_4: 0.8875 - val_loss: 0.9636 - val_auc_4: 0.8061
# Epoch 35/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6446 - auc_4: 0.8927 - val_loss: 0.9639 - val_auc_4: 0.8062
# Epoch 36/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6481 - auc_4: 0.8854 - val_loss: 0.9630 - val_auc_4: 0.8061
# Epoch 37/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6477 - auc_4: 0.8886 - val_loss: 0.9634 - val_auc_4: 0.8063
# Epoch 38/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6358 - auc_4: 0.8866 - val_loss: 0.9632 - val_auc_4: 0.8062
# Epoch 39/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6405 - auc_4: 0.8929 - val_loss: 0.9635 - val_auc_4: 0.8063
# Epoch 40/40
# 37/37 [==============================] - 57s 2s/step - loss: 0.6274 - auc_4: 0.8972 - val_loss: 0.9637 - val_auc_4: 0.8061
